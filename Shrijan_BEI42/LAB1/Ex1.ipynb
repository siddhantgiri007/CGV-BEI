# %% [markdown]
# ## Basic Input Output Operation in Python

# %%
# Out:
# Running cells with '.venv (Python 3.11.14)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/zeph/Documents/College/Computer_Graphics/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
